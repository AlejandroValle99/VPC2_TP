# %% [markdown]
# # 01 - Exploration
#
# Starting point for the computer vision experiments. Describe the dataset and the
# question this notebook is answering.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

from vpc2.data import io
from vpc2.utils import set_seed
from vpc2.utils import visualization as viz

set_seed(42)

DATA_DIR = Path("../data/raw")

# %% [markdown]
# ## Load the data

# %%
paths = io.list_images(DATA_DIR)
len(paths)

# %% [markdown]
# ## Inspect a few samples

# %%
images = io.load_images(paths[:8])
viz.show_grid(images)

# %% [markdown]
# ## Experiment
